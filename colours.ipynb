# %%
import os
import anywidget
import traitlets

# %%
bundler_output_dir = os.path.join(os.path.abspath(''), 'demo_widget', 'static')
print(bundler_output_dir)
# Out:
# C:\Users\sbranchett\work\demo-widget\demo_widget\static

# %%
class HelloWidget(anywidget.AnyWidget):
    def __init__(self, colour='red', **kwargs):
        super().__init__(**kwargs)
        self.colour = colour

    _esm = os.path.join(bundler_output_dir, 'script.js')
    # _css = os.path.join(bundler_output_dir, 'widget.css')
    
    colour = traitlets.Unicode().tag(sync=True)
    x_value = traitlets.Float().tag(sync=True)
    y_value = traitlets.Float().tag(sync=True)

# %%
attempt = HelloWidget(colour="green")
attempt
# Out:
# HelloWidget(colour='green')
